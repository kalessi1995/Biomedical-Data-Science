# %%
import numpy as np
from urllib.request import urlopen
import pandas as pd

# %%
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/postoperative-patient-data/post-operative.data"

"""Attribute Information:

1. L-CORE (patient's internal temperature in C):
              high (> 37), mid (>= 36 and <= 37), low (< 36)
     2. L-SURF (patient's surface temperature in C):
              high (> 36.5), mid (>= 36.5 and <= 35), low (< 35)
     3. L-O2 (oxygen saturation in %):
              excellent (>= 98), good (>= 90 and < 98),
              fair (>= 80 and < 90), poor (< 80)
     4. L-BP (last measurement of blood pressure):
              high (> 130/90), mid (<= 130/90 and >= 90/70), low (< 90/70)
     5. SURF-STBL (stability of patient's surface temperature):
              stable, mod-stable, unstable
     6. CORE-STBL (stability of patient's core temperature)
              stable, mod-stable, unstable
     7. BP-STBL (stability of patient's blood pressure)
              stable, mod-stable, unstable
     8. COMFORT (patient's perceived comfort at discharge, measured as
              an integer between 0 and 20)
     9. decision ADM-DECS (discharge decision):
              I (patient sent to Intensive Care Unit),
              S (patient prepared to go home),
              A (patient sent to general hospital floor)"""


names = ['L-CORE', 'L-SURF', 'L-O2', 'L-BP', 'SURF-STBL','CORE-STBL', 'BP-STBL','COMFORT', 'Decision']
df = c = pd.read_csv(url, names = names,comment='#')

# %%
df
# Out:
#    L-CORE L-SURF       L-O2  L-BP SURF-STBL CORE-STBL     BP-STBL COMFORT  \
# 0     mid    low  excellent   mid    stable    stable      stable      15
# 1     mid   high  excellent  high    stable    stable      stable      10
# 2    high    low  excellent  high    stable    stable  mod-stable      10
# 3     mid    low       good  high    stable  unstable  mod-stable      15
# 4     mid    mid  excellent  high    stable    stable      stable      10
# 5    high    low       good   mid    stable    stable    unstable      15
# 6     mid    low  excellent  high    stable    stable  mod-stable      05
# 7    high    mid  excellent   mid  unstable  unstable      stable      10
# 8     mid   high       good   mid    stable    stable      stable      10
# 9     mid    low  excellent   mid  unstable    stable  mod-stable      10
# 10    mid    mid       good   mid    stable    stable      stable      15
# 11    mid    low       good  high    stable    stable  mod-stable      10
# ...

# %%
#PREPROCESSING STEPS

# %%
df=df.replace({' A':'A'})

# %%
# adjusting the position of A within the table so it does not contain spaces for consistent data

# %%
df.COMFORT = df.COMFORT.apply(pd.to_numeric, errors = 'coerce')

# %%
# Replacing the question marks in the table to NaN to identify missing data that should be removed

# %%
df
# Out:
#    L-CORE L-SURF       L-O2  L-BP SURF-STBL CORE-STBL     BP-STBL  COMFORT  \
# 0     mid    low  excellent   mid    stable    stable      stable     15.0
# 1     mid   high  excellent  high    stable    stable      stable     10.0
# 2    high    low  excellent  high    stable    stable  mod-stable     10.0
# 3     mid    low       good  high    stable  unstable  mod-stable     15.0
# 4     mid    mid  excellent  high    stable    stable      stable     10.0
# 5    high    low       good   mid    stable    stable    unstable     15.0
# 6     mid    low  excellent  high    stable    stable  mod-stable      5.0
# 7    high    mid  excellent   mid  unstable  unstable      stable     10.0
# 8     mid   high       good   mid    stable    stable      stable     10.0
# 9     mid    low  excellent   mid  unstable    stable  mod-stable     10.0
# 10    mid    mid       good   mid    stable    stable      stable     15.0
# ...

# %%
df = df.dropna()

# %%
#Deleting rows within the table that contain NaN so the data can be read and sorted efficiently

# %%
df
# Out:
#    L-CORE L-SURF       L-O2  L-BP SURF-STBL CORE-STBL     BP-STBL  COMFORT  \
# 0     mid    low  excellent   mid    stable    stable      stable     15.0
# 1     mid   high  excellent  high    stable    stable      stable     10.0
# 2    high    low  excellent  high    stable    stable  mod-stable     10.0
# 3     mid    low       good  high    stable  unstable  mod-stable     15.0
# 4     mid    mid  excellent  high    stable    stable      stable     10.0
# 5    high    low       good   mid    stable    stable    unstable     15.0
# 6     mid    low  excellent  high    stable    stable  mod-stable      5.0
# 7    high    mid  excellent   mid  unstable  unstable      stable     10.0
# 8     mid   high       good   mid    stable    stable      stable     10.0
# 9     mid    low  excellent   mid  unstable    stable  mod-stable     10.0
# 10    mid    mid       good   mid    stable    stable      stable     15.0
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
sns.swarmplot(x=df['L-CORE'], y=df['COMFORT'], data=df, order = ['low','mid','high'])

# %%
#Patients with a core body temperature below 36 degrees Celcius felt significantly more moderate levels of comfort 
#than high levels. 
#Patients with a core body temperature greater than or equal to 36 degrees celcius and less than or equal to 37 
#degrees celcius experienced more moderate levels of comfort than high levels. 
#Patients with a core body temperature greater than 37 degrees Celcius experienced more moderate levels of comfort 
#than high levels.

# %%
sns.swarmplot(x=df['L-SURF'], y=df['COMFORT'], data=df, order = ['low','mid','high'])

# %%
#Patients with a surface body temperature below 35 degrees Celcius felt significantly more moderate levels of comfort 
#than high levels with an insignificant portion reporting low levels of comfort.
#Patients with a surface body temperature greater than or equal to 35 and less than or equal to 36.5 degrees Celcius 
#experienced more moderate levels of comfort than high levels 
#Patients with a surface body temperature greater than 36.5 degrees Celcius experienced more moderate levels of 
#comfort than high levels.

# %%
sns.swarmplot(x=df['L-O2'], y=df['COMFORT'], data=df, order = ['good','excellent'])

# %%
#Patients with an oxygen level greater than or equal to 90% saturation felt more moderate levels of comfort than high
#levels.
#Patients with an oxygen level greater than or equal to 98% saturation experienced significantly more moderate 
#levels of comfort than high levels with an insignificant portion reporting low levels of comfort.

# %%
sns.swarmplot(x=df['L-BP'], y=df['COMFORT'], data=df, order = ['low','mid','high'])

# %%
#Patients with a blood pressure less than 90/70 felt moderate levels of comfort.
#Patients with a blood pressure greater than or equal to 90/70 and less than or equal to 130/90 experienced 
#slightly more moderate levels of comfort than high levels with an insignificant portion reporting low levels of 
#comfort.
#Patients with a blood pressure greater than 130/90 experienced significantly more moderate levels of comfort than
#high levels.

# %%
sns.swarmplot(x=df['SURF-STBL'], y=df['COMFORT'], data=df, order = ['unstable','stable'])

# %%
#Patients with an unstable surface body temperature felt more moderate levels of comfort than high levels.
#Patients with a stable surface body temperature experienced significantly more moderate levels of comfort 
#than high levels.
#Without more data relationships between comfort and body surface temperature are difficult to conclude.

# %%
sns.swarmplot(x=df['CORE-STBL'], y=df['COMFORT'], data=df,order = ['unstable','mod-stable','stable'])

# %%
#Patients with an unstable internal core temperature felt slightly more moderate levels of comfort than high levels.
#Patients with a moderately stable internal core temperature experienced moderate levels of comfort.
#Patients with a stable internal core temperature equally experienced moderate and high levels of comfort with an 
#insignificant population reporting lower levels of comfort

# %%
sns.swarmplot(x=df['BP-STBL'], y=df['COMFORT'], data=df, order = ['unstable','mod-stable','stable'])

# %%
#Patients with unstable blood pressure felt more moderate levels of comfort than high levels.
#Patients with moderately stable blood pressure experienced significantly more moderate levels of comfort than 
#high levels.
#Patients with stable blood pressure experienced slightly more moderate levels of comfort than high levels.

# %%
sns.swarmplot(x=df['Decision'], y=df['COMFORT'], data=df)

# %%
#Patients sent to the general hospital floor equally experienced both high and moderate levels of comfort. 
#Patients sent home experienced more moderate levels of comfort than high levels with an insignificant 
#population reporting lower levels of comfort.
#Patients sent to the ICU experienced moderate levels of comfort.
